# %% [markdown]
# # Exploring Embedding Models in Langchain

# %% [markdown]
# # Install OpenAI, HuggingFace and Langchain

# %%
# !pip install langchain==0.3.11
# !pip install langchain-openai==0.2.12
# !pip install langchain-community==0.3.11
# !pip install langchain-huggingface==0.1.2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 28.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.9 MB/s eta 0:00:00
# ...

# %%
from getpass import getpass
OPENAI_KEY = getpass('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')
